# %% [markdown]
# <a href="https://colab.research.google.com/github/PulkitKhator/Menu-Parsing/blob/main/MenuParsingAddOns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import urllib.request, json

# %%
with urllib.request.urlopen("https://amfprodneblobstorage.blob.core.windows.net/amfprodneblobstorage/production/v1/kfc_uae_1_En.json?sv=2019-02-02&ss=bfqt&srt=sco&sp=rl&se=2029-04-09T19:07:24Z&st=2020-04-09T11:07:24Z&spr=https&sig=Z67UuDjY4QScWJCAMeXZmMn7VLH%2F3uL6xv6vpXnInOA%3D") as url:
    data = json.loads(url.read().decode())
    print(data)
# Out:
# {'id': 1, 'menuTempId': 17, 'conceptId': 3, 'menuId': 1, 'currency': 'AED', 'language': 'En', 'updatedAt': 1632896918000, 'countryId': 'AE', 'version': 'v1', 'categories': [{'position': 1, 'id': 4, 'name': 'Deals', 'isHidden': 0, 'categoryCode': 'Deals', 'products': [{'id': 230, 'position': 20, 'name': '24 PCs Double Bucket', 'description': '', 'services': None, 'inSide': 1, 'finalPrice': 135, 'specialPrice': 135, 'strikeOutPrice': 135, 'catId': 4, 'promoId': 388, 'metaKeyword': ['24 PCs Double Bucket'], 'bundleProductOptions': [{'position': 1, 'name': '24 PCs Double Bucket', 'title': '24 PCs Double Bucket', 'subtitle': '24 PCs Double Bucket', 'ingredient': 0, 'type': 'radio', 'compId': 1, 'isModifier': 0, 'imageThumbnail': '/imagestemp/0.png', 'productLinks': [{'position': 1, 'option_id': 545, 'selection_id': 2391, 'price': 0, 'id': 226, 'name': '24 PCs Double Bucket', 'title': '24 PCs Double Bucket', 'imageThumbnail': '/imagestemp/410068.png', 'selectionQty': 1, 'subOptions': [], 'selected': 1, 'sku': 410068, 'sdmId': 410068, 'default': 1, 'modGroupId': -1, 'dependentSteps': [2]}], 'maximumQty': 0, 'minimumQty': 0, 'isAddon': 0, 'isDependent': 0}, {'position': 2, 'name': 'Choice Of Chicken', 'title': 'Choice Of Chicken', 'subtitle': 'Choice Of Chicken', 'ingredient': 0, 'type': 'stepper', 'compId': 1, 'isModifier': 1, 'imageThumbnail': '/imagestemp/0.png', 'productLinks': [{'position': 1, 'option_id': 546, 'selection_id': 2392, 'price': 0, 'id': 87, 'name': 'Chicken Pc - Original', 'title': 'Chicken Pc - Original', 'imageThumbnail': '/imagestemp/910001.png', 'selectionQty': 12, 'subOptions': [], 'selected': 1, 'sku': 910001, 'sdmId': 910001, 'default': 0, 'modGroupId': 10207, 'dependentSteps': []}, {'position': 2, 'option_id': 546, 'selection_id': 2393, 'price': 0, 'id': 88, 'name': 'Chicken Pc - Spicy', 'title': 'Chicken Pc - Spicy', 'imageThumbnail': '/imagestemp/910002.png', 'selectionQty': 12, 'subOptions': [], 'selected': 0, 'sku': 910002, 'sdmId': 910002, 'default': 0, 'modGroupId': 10207, 'dependentSteps': []}], 'maximumQty': 24, 'minimumQty': 24, 'isAddon': 0, 'isDependent': 1}, {'position': 3, 'name': 'Select your favorite side item', 'title': 'Select your favorite side item', 'subtitle': 'Select your favorite side item', 'ingredient': 0, 'type': 'radio', 'compId': 2, 'isModifier': 0, 'imageThumbnail': '/imagestemp/0.png', 'productLinks': [{'position': 1, 'option_id': 547, 'selection_id': 2394, 'price': 0, 'id': 51, 'name': 'Coleslaw Salad Large', 'title': 'Coleslaw Salad Large', 'imageThumbnail': '/imagestemp/510002.png', 'selectionQty': 1, 'subOptions': [], 'selected': 0, 'sku': 510002, 'sdmId': 510002, 'default': 0, 'modGroupId': -1, 'dependentSteps': []}, {'position': 2, 'option_id': 547, 'selection_id': 2395, 'price': 0, 'id': 68, 'name': 'Family Fries', 'title': 'Family Fries', 'imageThumbnail': '/imagestemp/510005.png', 'selectionQty': 1, 'subOptions': [], 'selected': 1, 'sku': 510005, 'sdmId': 510005, 'default': 1, 'modGroupId': -1, 'dependentSteps': []}, {'position': 3, 'option_id': 547, 'selection_id': 2396, 'price': 3, 'id': 72, 'name': 'Family Fries Spicy', 'title': 'Family Fries Spicy', 'imageThumbnail': '/imagestemp/510014.png', 'selectionQty': 1, 'subOptions': [], 'selected': 0, 'sku': 510014, 'sdmId': 510014, 'default': 0, 'modGroupId': -1, 'dependentSteps': []}, {'position': 4, 'option_id': 547, 'selection_id': 2397, 'price': 5, 'id': 64, 'name': 'Loaded Fries Family', 'title': 'Loaded Fries Family', 'imageThumbnail': '/imagestemp/510030.png', 'selectionQty': 1, 'subOptions': [], 'selected': 0, 'sku': 510030, 'sdmId': 510030, 'default': 0, 'modGroupId': -1, 'dependentSteps': []}, {'position': 5, 'option_id': 547, 'selection_id': 2399, 'price': 5, 'id': 152, 'name': 'Family Loaded Fries Pepper - Chili Sauce', 'title': 'Family Loaded Fries Pepper - Chili Sauce', 'imageThumbnail': '/imagestemp/510080.png', 'selectionQty': 1, 'subOptions': [], 'selected': 0, 'sku': 510080, 'sdmId': 510080, 'default': 0, ...

# %%
def menu(data):
  df = pd.DataFrame.from_dict(data)
  result = pd.DataFrame({'ProductPrice':[],'CategoryId':[],'CategoryName':[],'ProductId':[],'ProductName':[],'SDMID':[],'AddOns':[]})
  for row in range(len(df)):
    ProductPrice = []
    CategoryId = []
    CategoryName = []
    ProductId = []
    ProductName = []
    SDMID = []
    AddOns = []
    df1 = pd.DataFrame.from_dict(df['categories'][row])
    for j in range(len(df1)):
      df2 = pd.DataFrame.from_dict(df1['products'][j],orient='index').transpose()
      if (len(df2['bundleProductOptions'][0])>=2):
        df3 = pd.DataFrame.from_dict(df2['bundleProductOptions'][0][1])
        AO = []
        if (len(df3)!=0):
          for i in range(len(df3)):
            if (df3['isAddon'][i] == 1):
              df4 = pd.DataFrame.from_dict(df3['productLinks'][i],orient='index').transpose()
              AO.append(df4['name'][0])
      else:
        AO = []
      ProductPrice.append(df2['finalPrice'][0])
      CategoryId.append(str(df1['id'][0]))
      CategoryName.append(df1['categoryCode'][0])
      ProductId.append(str(df2['id'][0]))
      ProductName.append(df2['name'][0])
      SDMID.append(str(df2['sdmId'][0]))
      AddOns.append(AO)
    R = pd.DataFrame(list(zip(ProductPrice, CategoryId, CategoryName, ProductId, ProductName, SDMID,AddOns)), columns = ['ProductPrice','CategoryId','CategoryName','ProductId','ProductName','SDMID','AddOns'])
    result = result.append(R, ignore_index = True)
  return result

# %%
def menu(data):
  df = pd.DataFrame.from_dict(data)
  result = pd.DataFrame({'ProductPrice':[],'CategoryId':[],'CategoryName':[],'ProductId':[],'ProductName':[],'SDMID':[],'AddOns':[]})
  for row in range(len(df)):
    ProductPrice = []
    CategoryId = []
    CategoryName = []
    ProductId = []
    ProductName = []
    SDMID = []
    AddOns = []
    df1 = pd.DataFrame.from_dict(df['categories'][row])
    for j in range(len(df1)):
      df2 = pd.DataFrame.from_dict(df1['products'][j],orient='index').transpose()
      AO = []
      for k in range(len(df2['bundleProductOptions'][0])):
        if(type(df2['bundleProductOptions'][0][k]) == dict):
          if('isAddon' in df2['bundleProductOptions'][0][k].keys()):
            if(df2['bundleProductOptions'][0][k]['isAddon']==1):
              for l in range(len(df2['bundleProductOptions'][0][k]['productLinks'])):
                AO.append(df2['bundleProductOptions'][0][k]['productLinks'][l]['name'])
      ProductPrice.append(df2['finalPrice'][0])
      CategoryId.append(str(df1['id'][0]))
      CategoryName.append(df1['categoryCode'][0])
      ProductId.append(str(df2['id'][0]))
      ProductName.append(df2['name'][0])
      SDMID.append(str(df2['sdmId'][0]))
      AddOns.append(AO)
    R = pd.DataFrame(list(zip(ProductPrice, CategoryId, CategoryName, ProductId, ProductName, SDMID,AddOns)), columns = ['ProductPrice','CategoryId','CategoryName','ProductId','ProductName','SDMID','AddOns'])
    result = result.append(R, ignore_index = True)
  return result

# %%
def menu(data):
  df = pd.DataFrame.from_dict(data)
  result = pd.DataFrame({'ProductPrice':[],'CategoryId':[],'CategoryName':[],'ProductId':[],'ProductName':[],'SDMID':[],'AddOns':[]})
  for row in range(len(df)):
    ProductPrice = []
    CategoryId = []
    CategoryName = []
    ProductId = []
    ProductName = []
    SDMID = []
    AddOns = []
    df1 = pd.DataFrame.from_dict(df['categories'][row])
    for j in range(len(df1)):
      df2 = pd.DataFrame.from_dict(df1['products'][j],orient='index').transpose()
      AO = []
      for k in range(len(df2['bundleProductOptions'][0])):
        if(type(df2['bundleProductOptions'][0][k]) == dict):
          if(df2['bundleProductOptions'][0][k]['name'] in ["Select your favorite Addon","Addon","AddOn","Addons","AddOns"]):
          #if((df2['bundleProductOptions'][0][k]['name']=="Select your favorite Addon") in df2['bundleProductOptions'][0][k].keys()):
            #if((df2['bundleProductOptions'][0][k]['isAddon']==1) | (df2['bundleProductOptions'][0][k]['isAddon']==0)):
            for l in range(len(df2['bundleProductOptions'][0][k]['productLinks'])):
              AO.append(df2['bundleProductOptions'][0][k]['productLinks'][l]['name'])
      ProductPrice.append(df2['finalPrice'][0])
      CategoryId.append(str(df1['id'][0]))
      CategoryName.append(df1['categoryCode'][0])
      ProductId.append(str(df2['id'][0]))
      ProductName.append(df2['name'][0])
      SDMID.append(str(df2['sdmId'][0]))
      AddOns.append(AO)
    R = pd.DataFrame(list(zip(ProductPrice, CategoryId, CategoryName, ProductId, ProductName, SDMID,AddOns)), columns = ['ProductPrice','CategoryId','CategoryName','ProductId','ProductName','SDMID','AddOns'])
    result = result.append(R, ignore_index = True)
  return result

# %%
def web_link(link):
  with urllib.request.urlopen(link) as url:
    data = json.loads(url.read().decode())
    return menu(data)

# %%
link = "https://amfprodneblobstorage.blob.core.windows.net/amfprodneblobstorage/production/v1/kfc_uae_1_En.json?sv=2019-02-02&ss=bfqt&srt=sco&sp=rl&se=2029-04-09T19:07:24Z&st=2020-04-09T11:07:24Z&spr=https&sig=Z67UuDjY4QScWJCAMeXZmMn7VLH%2F3uL6xv6vpXnInOA%3D"
uae = web_link(link)
uae
# Out:
#     ProductPrice CategoryId CategoryName  ...           ProductName SDMID AddOns
# 0          135.0          4        Deals  ...  24 PCs Double Bucket   175     []
# 1           59.0          4        Deals  ...       Super Mega Deal   247     []
# 2           32.5          4        Deals  ...     Super Dinner Meal   284     []
# 3           25.0          4        Deals  ...          Mighty Twist   268     []
# 4           32.5          4        Deals  ...    Zinger Blaze Twist   349     []
# ..           ...        ...          ...  ...                   ...   ...    ...
# 66           9.5         10    Beverages  ...                 Pepsi     1     []
# 67           9.5         10    Beverages  ...            Diet Pepsi     5     []
# 68           9.5         10    Beverages  ...                  7 UP     6     []
# 69           9.5         10    Beverages  ...          Mountain Dew     7     []
# 70           9.5         10    Beverages  ...               Mirinda     8     []
#
# [71 rows x 7 columns]

# %%
link = "https://amfprodneblobstorage.blob.core.windows.net/amfprodneblobstorage/production/v1/kfc_egy_2_14_En.json?sv=2019-02-02&ss=bfqt&srt=sco&sp=rl&se=2029-04-09T19:07:24Z&st=2020-04-09T11:07:24Z&spr=https&sig=Z67UuDjY4QScWJCAMeXZmMn7VLH%2F3uL6xv6vpXnInOA%3D"
egy = web_link(link)
egy
# Out:
#     ProductPrice  ...                                             AddOns
# 0           85.0  ...                                        [No Add On]
# 1          122.0  ...  [No Add On, Apple Pie, 2 Strips Pcs - Original...
# 2          125.0  ...                                                 []
# 3           84.0  ...                                                 []
# 4           90.0  ...                                                 []
# ..           ...  ...                                                ...
# 71          26.0  ...                                                 []
# 72           4.0  ...                                                 []
# 73          10.0  ...                                                 []
# 74           0.0  ...                                                 []
# 75           0.0  ...                                                 []
#
# [76 rows x 7 columns]

# %%
egy.head(30)
# Out:
#     ProductPrice  ...                                             AddOns
# 0           85.0  ...                                        [No Add On]
# 1          122.0  ...  [No Add On, Apple Pie, 2 Strips Pcs - Original...
# 2          125.0  ...                                                 []
# 3           84.0  ...                                                 []
# 4           90.0  ...                                                 []
# 5          368.0  ...                   [No Add On, 10 pc Shrimp Add-On]
# 6          448.0  ...                   [No Add On, 10 pc Shrimp Add-On]
# 7           99.0  ...                                        [No Add On]
# 8          288.0  ...                   [No Add On, 10 pc Shrimp Add-On]
# 9           96.0  ...  [No Add On, Apple Pie, 2 Strips Pcs - Original...
# 10          70.0  ...                                                 []
# 11          36.0  ...                                                 []
# 12          36.0  ...                                                 []
# 13          54.0  ...                                                 []
# 14         106.0  ...  [No Add On, Waffle Fries Large, Apple Pie, 2 S...
# 15          86.0  ...  [No Add On, Waffle Fries Large, Apple Pie, 2 S...
# 16          84.0  ...                                        [No Add On]
# 17          50.0  ...                                        [No Add On]
# 18          46.0  ...                                                 []
# 19          92.0  ...                                        [No Add On]
# 20          83.0  ...                                        [No Add On]
# 21          68.0  ...                                        [No Add On]
# 22          60.0  ...                                        [No Add On]
# 23          92.0  ...                                                 []
# 24          60.0  ...                                        [No Add On]
# 25          78.0  ...  [No Add On, Waffle Fries Large, Apple Pie, 2 S...
# 26         102.0  ...  [No Add On, Waffle Fries Large, Apple Pie, 2 S...
# 27          65.0  ...  [No Add On, Waffle Fries Large, Apple Pie, 2 S...
# 28          79.0  ...                                                 []
# 29          79.0  ...                                                 []
#
# [30 rows x 7 columns]

# %%
link = "https://amfprodneblobstorage.blob.core.windows.net/amfprodneblobstorage/production/v1/kfc_kwt_1_13_En.json?sv=2019-02-02&ss=bfqt&srt=sco&sp=rl&se=2029-04-09T19:07:24Z&st=2020-04-09T11:07:24Z&spr=https&sig=Z67UuDjY4QScWJCAMeXZmMn7VLH%2F3uL6xv6vpXnInOA%3D"
kwt = web_link(link)
kwt
# Out:
#     ProductPrice CategoryId  ...   SDMID AddOns
# 0           4.25         34  ...     131     []
# 1           2.50         34  ...     115     []
# 2           2.35         34  ...     178     []
# 3           2.00         34  ...     181     []
# 4           3.10         34  ...     188     []
# ..           ...        ...  ...     ...    ...
# 80          0.65         35  ...  510036     []
# 81          0.60         35  ...  510012     []
# 82          0.50         35  ...  510004     []
# 83          0.05         35  ...  814011     []
# 84          0.05         35  ...  810005     []
#
# [85 rows x 7 columns]

# %%
uae['AddOns'][4]
# Out:
# ['Coleslaw Salad Small',
#  '2 Strips pcs – Original',
#  '2 Strips pcs – Spicy',
#  'Rice',
#  'Coleslaw Large Add On']

# %%
uae['AddOns'][30]
# Out:
# []

# %%
link = "https://amfprodneblobstorage.blob.core.windows.net/amfprodneblobstorage/production/v1/kfc_uae_1_Ar.json?sv=2019-02-02&ss=bfqt&srt=sco&sp=rl&se=2029-04-09T19:07:24Z&st=2020-04-09T11:07:24Z&spr=https&sig=Z67UuDjY4QScWJCAMeXZmMn7VLH%2F3uL6xv6vpXnInOA%3D"
uae_ar = web_link(link)
uae_ar
# Out:
#     ProductPrice  ...                                             AddOns
# 0          135.0  ...                                                 []
# 1           59.0  ...  [ أرز, إضافة كول سلو حجم كبير, 5 قطع إستربس - ...
# 2           32.5  ...  [ كول سلو صغير,  قطعتين استربس - عادي,  قطعتين...
# 3           25.0  ...  [ كول سلو صغير,  قطعتين استربس - عادي,  قطعتين...
# 4           32.5  ...  [ كول سلو صغير,  قطعتين استربس - عادي,  قطعتين...
# ..           ...  ...                                                ...
# 67           9.5  ...                                                 []
# 68           9.5  ...                                                 []
# 69           9.5  ...                                                 []
# 70           9.5  ...                                                 []
# 71           9.5  ...                                                 []
#
# [72 rows x 7 columns]

# %%
uae_ar['AddOns'][4]
# Out:
# [' كول سلو صغير',
#  ' قطعتين استربس - عادي',
#  ' قطعتين استربس - سبايسي',
#  ' أرز',
#  'إضافة كول سلو حجم كبير']

# %%
links = [
    "https://amfprodneblobstorage.blob.core.windows.net/amfprodneblobstorage/production/v1/kfc_uae_1_En.json?sv=2019-02-02&ss=bfqt&srt=sco&sp=rl&se=2029-04-09T19:07:24Z&st=2020-04-09T11:07:24Z&spr=https&sig=Z67UuDjY4QScWJCAMeXZmMn7VLH%2F3uL6xv6vpXnInOA%3D",
    "https://amfprodneblobstorage.blob.core.windows.net/amfprodneblobstorage/production/v1/kfc_uae_1_Ar.json?sv=2019-02-02&ss=bfqt&srt=sco&sp=rl&se=2029-04-09T19:07:24Z&st=2020-04-09T11:07:24Z&spr=https&sig=Z67UuDjY4QScWJCAMeXZmMn7VLH%2F3uL6xv6vpXnInOA%3D",
    "https://amfprodneblobstorage.blob.core.windows.net/amfprodneblobstorage/production/v1/kfc_ksa_1_5_En.json?sv=2019-02-02&ss=bfqt&srt=sco&sp=rl&se=2029-04-09T19:07:24Z&st=2020-04-09T11:07:24Z&spr=https&sig=Z67UuDjY4QScWJCAMeXZmMn7VLH%2F3uL6xv6vpXnInOA%3D",
    "https://amfprodneblobstorage.blob.core.windows.net/amfprodneblobstorage/production/v1/kfc_ksa_1_5_Ar.json?sv=2019-02-02&ss=bfqt&srt=sco&sp=rl&se=2029-04-09T19:07:24Z&st=2020-04-09T11:07:24Z&spr=https&sig=Z67UuDjY4QScWJCAMeXZmMn7VLH%2F3uL6xv6vpXnInOA%3D",
    "https://amfprodneblobstorage.blob.core.windows.net/amfprodneblobstorage/production/v1/kfc_kwt_1_13_En.json?sv=2019-02-02&ss=bfqt&srt=sco&sp=rl&se=2029-04-09T19:07:24Z&st=2020-04-09T11:07:24Z&spr=https&sig=Z67UuDjY4QScWJCAMeXZmMn7VLH%2F3uL6xv6vpXnInOA%3D",
    "https://amfprodneblobstorage.blob.core.windows.net/amfprodneblobstorage/production/v1/kfc_kwt_1_13_Ar.json?sv=2019-02-02&ss=bfqt&srt=sco&sp=rl&se=2029-04-09T19:07:24Z&st=2020-04-09T11:07:24Z&spr=https&sig=Z67UuDjY4QScWJCAMeXZmMn7VLH%2F3uL6xv6vpXnInOA%3D",
    "https://amfprodneblobstorage.blob.core.windows.net/amfprodneblobstorage/production/v1/kfc_qat_2_5_En.json?sv=2019-02-02&ss=bfqt&srt=sco&sp=rl&se=2029-04-09T19:07:24Z&st=2020-04-09T11:07:24Z&spr=https&sig=Z67UuDjY4QScWJCAMeXZmMn7VLH%2F3uL6xv6vpXnInOA%3D",
    "https://amfprodneblobstorage.blob.core.windows.net/amfprodneblobstorage/production/v1/kfc_qat_2_5_Ar.json?sv=2019-02-02&ss=bfqt&srt=sco&sp=rl&se=2029-04-09T19:07:24Z&st=2020-04-09T11:07:24Z&spr=https&sig=Z67UuDjY4QScWJCAMeXZmMn7VLH%2F3uL6xv6vpXnInOA%3D",
    "https://amfprodneblobstorage.blob.core.windows.net/amfprodneblobstorage/production/v1/kfc_egy_2_14_En.json?sv=2019-02-02&ss=bfqt&srt=sco&sp=rl&se=2029-04-09T19:07:24Z&st=2020-04-09T11:07:24Z&spr=https&sig=Z67UuDjY4QScWJCAMeXZmMn7VLH%2F3uL6xv6vpXnInOA%3D",
    "https://amfprodneblobstorage.blob.core.windows.net/amfprodneblobstorage/production/v1/kfc_egy_2_14_Ar.json?sv=2019-02-02&ss=bfqt&srt=sco&sp=rl&se=2029-04-09T19:07:24Z&st=2020-04-09T11:07:24Z&spr=https&sig=Z67UuDjY4QScWJCAMeXZmMn7VLH%2F3uL6xv6vpXnInOA%3D",
    "https://amfprodneblobstorage.blob.core.windows.net/amfprodneblobstorage/production/v1/kfc_omn_2_6_En.json?sv=2019-02-02&ss=bfqt&srt=sco&sp=rl&se=2029-04-09T19:07:24Z&st=2020-04-09T11:07:24Z&spr=https&sig=Z67UuDjY4QScWJCAMeXZmMn7VLH%2F3uL6xv6vpXnInOA%3D",
    "https://amfprodneblobstorage.blob.core.windows.net/amfprodneblobstorage/production/v1/kfc_omn_2_6_Ar.json?sv=2019-02-02&ss=bfqt&srt=sco&sp=rl&se=2029-04-09T19:07:24Z&st=2020-04-09T11:07:24Z&spr=https&sig=Z67UuDjY4QScWJCAMeXZmMn7VLH%2F3uL6xv6vpXnInOA%3D",
    "https://amfprodneblobstorage.blob.core.windows.net/amfprodneblobstorage/production/v1/kfc_bhr_1_6_En.json?sv=2019-02-02&ss=bfqt&srt=sco&sp=rl&se=2029-04-09T19:07:24Z&st=2020-04-09T11:07:24Z&spr=https&sig=Z67UuDjY4QScWJCAMeXZmMn7VLH%2F3uL6xv6vpXnInOA%3D",
    "https://amfprodneblobstorage.blob.core.windows.net/amfprodneblobstorage/production/v1/kfc_bhr_1_6_Ar.json?sv=2019-02-02&ss=bfqt&srt=sco&sp=rl&se=2029-04-09T19:07:24Z&st=2020-04-09T11:07:24Z&spr=https&sig=Z67UuDjY4QScWJCAMeXZmMn7VLH%2F3uL6xv6vpXnInOA%3D"
]

sheetnames = ["UAE_En", "UAE_Ar", "KSA_En", "KSA_Ar", "KWT_En", "KWT_Ar", "QAT_En", "QAT_Ar", "EGY_En", "EGY_Ar", "OMN_En", "OMN_Ar", "BHR_En", "BHR_Ar"]
urlschema = ["kfcme", "kfcme", "kfcksa", "kfcksa", "kfckwt", "kfckwt", "kfcqatar", "kfcqatar", "kfcegypt", "kfcegypt", "kfcoman", "kfcoman", "kfcbahrain", "kfcbahrain"]

# %%
with pd.ExcelWriter('TheAddOnSheet.xlsx') as writer:
  for i in range(len(links)):
    df = web_link(links[i])
    #df = df.loc[(df['CategoryName']!="Sides & Desserts") & (df['CategoryName']!="Free Product") 
       #& (df['CategoryName']!="Upsell")& (df['CategoryName']!="Beverages")]
    df.to_excel(writer, sheet_name=sheetnames[i],index=False)
